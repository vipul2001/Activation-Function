# %%
from __future__ import print_function
import numpy
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torchvision.datasets import ImageFolder
from PIL import Image
import numpy as np
from torchvision import datasets, transforms
from torch.autograd import Variable

# %%
class Net(nn.Module):
    """ConvNet -> Max_Pool -> RELU -> ConvNet -> Max_Pool -> RELU -> FC -> RELU -> FC -> SOFTMAX"""
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 20, 5, 1)
        self.bn1=torch.nn.BatchNorm2d(20)
        self.w1_1 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.w2_1 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.w3_1 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.conv2 = nn.Conv2d(20, 50, 5, 1)
        self.bn2=torch.nn.BatchNorm2d(50)
        self.w1_2 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.w2_2 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.w3_2 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.fc1 = nn.Linear(4*4*50, 500)
        self.bn3=torch.nn.BatchNorm1d(500)
        self.w1_3 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.w2_3 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.w3_3 = torch.nn.Parameter(data=torch.abs(torch.randn (1)), requires_grad=True)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = ((self.bn1(self.conv1(x))))
        self.w1_1.data=self.w1_1.data.clamp(min=0)
        self.w2_1.data=self.w2_1.data.clamp(min=0)
        self.w3_1.data=self.w3_1.data.clamp(min=0)
        self.w1_2.data=self.w1_2.data.clamp(min=0)
        self.w2_2.data=self.w2_2.data.clamp(min=0)
        self.w3_2.data=self.w3_2.data.clamp(min=0)
        self.w1_3.data=self.w1_3.data.clamp(min=0)
        self.w2_3.data=self.w2_3.data.clamp(min=0)
        self.w3_3.data=self.w3_3.data.clamp(min=0)
        x =(self.w1_1*F.relu(x)+self.w2_1*F.tanh(x)+self.w3_1*torch.sin(x))/(self.w1_1+self.w2_1+self.w3_1+1e-5)
        x = F.max_pool2d(x, 2, 2)
        x = ((self.bn2(self.conv2(x))))
        x =(self.w1_2*F.relu(x)+self.w2_2*F.tanh(x)+self.w3_2*torch.sin(x))/(self.w1_2+self.w2_2+self.w3_2+1e-5)
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*50)
        x =(self.bn3(self.fc1(x)))
        x =(self.w1_3*F.relu(x)+self.w2_3*F.tanh(x)+self.w3_3*torch.sin(x))/(self.w1_3+self.w2_3+self.w3_3+1e-5)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
n_epochs = 30
batch_size_train = 64
batch_size_test = 1000
learning_rate =1e-4
momentum = 0.5
log_interval = 200

# %%
# transforms to apply to the data
trans = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

# MNIST dataset
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.FashionMNIST('/d/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=True)

test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.FashionMNIST('/d/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)

# %%
examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)

# %%
example_data.shape
# Out:
# torch.Size([1000, 1, 28, 28])

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Ground Truth: {}".format(example_targets[i]))
  plt.xticks([])
  plt.yticks([])
fig

# %%
network = Net()

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

# %%
network.cuda()
# Out:
# Net(
#   (conv1): Conv2d(1, 20, kernel_size=(5, 5), stride=(1, 1))
#   (bn1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#   (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=800, out_features=500, bias=True)
#   (bn3): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
def train(epoch):
  network.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data=data.cuda()
    target=target.cuda()
    optimizer.zero_grad()
    output = network(data)
    loss = F.nll_loss(output, target)
    loss.backward()
    optimizer.step()
    if batch_idx % log_interval == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        epoch, batch_idx * len(data), len(train_loader.dataset),
        100. * batch_idx / len(train_loader), loss.item()))
      train_losses.append(loss.item())
      train_counter.append(
        (batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))

# %%
def test():
  network.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      data=data.cuda()
      target=target.cuda()
      output = network(data)
      test_loss += F.nll_loss(output, target, size_average=False).item()
      pred = output.data.max(1, keepdim=True)[1]
      correct += pred.eq(target.data.view_as(pred)).sum()
  test_loss /= len(test_loader.dataset)
  test_losses.append(test_loss)
  test_counter.append(
        (batch_idx*64) + ((epoch-1)*len(test_loader.dataset)))
  print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss, correct, len(test_loader.dataset),
    100. * correct / len(test_loader.dataset)))
  print(network.w1_1/(network.w1_1+network.w2_1+network.w3_1))
  print(network.w2_1/(network.w1_1+network.w2_1+network.w3_1))
  print(network.w3_1/(network.w1_1+network.w2_1+network.w3_1))
  print(network.w1_2/(network.w1_2+network.w2_2+network.w3_2))
  print(network.w2_2/(network.w1_2+network.w2_2+network.w3_2))
  print(network.w3_2/(network.w1_2+network.w2_2+network.w3_2))

# %%
optimizer = torch.optim.Adam(
    [
        {"params": network.conv1.parameters(), "lr": 1e-3},
        {"params": network.conv2.parameters(), "lr": 1e-3},
        {"params": network.bn1.parameters(), "lr": 1e-3},
        {"params": network.bn2.parameters(), "lr": 1e-3},
        {"params": network.bn3.parameters(), "lr": 1e-3},
        {"params": network.fc1.parameters(), "lr": 1e-3},
        {"params": network.fc2.parameters(), "lr": 1e-3},
        {"params": network.w1_1},
        {"params": network.w2_1},
        {"params": network.w3_1},
        {"params": network.w1_2},
        {"params": network.w2_2},
        {"params": network.w3_2},
        {"params": network.w1_3},
        {"params": network.w2_3},
        {"params": network.w3_3},
        
    ],
    lr=0,
)
for epoch in range(1, 10 + 1):
  train(epoch)
  test()
optimizer = torch.optim.Adam(
    [
        {"params": network.conv1.parameters(), "lr": 0},
        {"params": network.conv2.parameters(), "lr": 0},
        {"params": network.bn1.parameters(), "lr":0},
        {"params": network.bn2.parameters(), "lr": 0},
        {"params": network.bn3.parameters(), "lr": 0},
        {"params": network.fc1.parameters(), "lr": 0},
        {"params": network.fc2.parameters(), "lr": 0},
        {"params": network.w1_1},
        {"params": network.w2_1},
        {"params": network.w3_1},
        {"params": network.w1_2},
        {"params": network.w2_2},
        {"params": network.w3_2},
        {"params": network.w1_3},
        {"params": network.w2_3},
        {"params": network.w3_3},
        
    ],
    lr=1e-2,
)
for epoch in range(1, 20 + 1):
  train(epoch)
  test()
optimizer = torch.optim.Adam(
    [
        {"params": network.conv1.parameters(), "lr": 1e-3},
        {"params": network.conv2.parameters(), "lr": 1e-3},
        {"params": network.bn1.parameters(), "lr": 1e-3},
        {"params": network.bn2.parameters(), "lr": 1e-3},
        {"params": network.bn3.parameters(), "lr": 1e-3},
        {"params": network.fc1.parameters(), "lr": 1e-3},
        {"params": network.fc2.parameters(), "lr": 1e-3},
        {"params": network.w1_1, "lr": 0},
        {"params": network.w2_1, "lr": 0},
        {"params": network.w3_1, "lr": 0},
        {"params": network.w1_2, "lr": 0},
        {"params": network.w2_2, "lr": 0},
        {"params": network.w3_2, "lr": 0},
        {"params": network.w1_3, "lr": 0},
        {"params": network.w2_3, "lr": 0},
        {"params": network.w3_3, "lr": 0},
        
    ],
    lr=1e-4,
)
for epoch in range(1, 10 + 1):
  train(epoch)
  test()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.323608
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.488469
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.394518
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.275593
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.325886
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 0.3066, Accuracy: 8884/10000 (89%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.246810
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.298325
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.241293
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.220154
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.228995
#
# Test set: Avg. loss: 0.2867, Accuracy: 8960/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.164035
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.269527
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.242163
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.128414
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.110088
#
# Test set: Avg. loss: 0.2885, Accuracy: 8988/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.438397
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.172499
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.192270
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.077898
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.083951
#
# Test set: Avg. loss: 0.2881, Accuracy: 9001/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.251028
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.141158
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.160091
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.184267
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.149607
#
# Test set: Avg. loss: 0.2764, Accuracy: 9019/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.033861
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.086798
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.169375
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.159974
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.032712
#
# Test set: Avg. loss: 0.3104, Accuracy: 8967/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.084257
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.041445
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.082026
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.160611
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.034856
#
# Test set: Avg. loss: 0.2899, Accuracy: 9045/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.083588
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.013539
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.021214
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.040414
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.059947
#
# Test set: Avg. loss: 0.3073, Accuracy: 9059/10000 (91%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.039720
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.023591
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.163714
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.035223
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.027412
#
# Test set: Avg. loss: 0.3226, Accuracy: 9091/10000 (91%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.073472
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.037651
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.033180
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.039252
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.016680
#
# Test set: Avg. loss: 0.3691, Accuracy: 9008/10000 (90%)
#
# tensor([0.4044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3999], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1957], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2194], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.019626
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.089081
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.085994
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.045838
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.083824
#
# Test set: Avg. loss: 0.3290, Accuracy: 9096/10000 (91%)
#
# tensor([0.4917], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1831], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3252], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2933], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6946], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0121], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.075944
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.033099
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.080356
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.011397
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.029016
#
# Test set: Avg. loss: 0.3271, Accuracy: 9103/10000 (91%)
#
# tensor([0.5031], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1582], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3386], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2926], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7037], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0038], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.042709
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.063315
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.066390
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.029962
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.133188
#
# Test set: Avg. loss: 0.3255, Accuracy: 9109/10000 (91%)
#
# tensor([0.5314], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1712], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2972], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6662], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0366], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.052746
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.063338
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.011130
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.033096
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.062222
#
# Test set: Avg. loss: 0.3254, Accuracy: 9099/10000 (91%)
#
# tensor([0.4994], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1609], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3397], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2629], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7064], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0307], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.056446
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.031424
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.015386
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.023229
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.041879
#
# Test set: Avg. loss: 0.3275, Accuracy: 9112/10000 (91%)
#
# tensor([0.4804], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1738], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3458], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2785], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7141], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0074], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.042282
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.014401
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.032362
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.067374
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.038915
#
# Test set: Avg. loss: 0.3250, Accuracy: 9101/10000 (91%)
#
# tensor([0.5411], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1477], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3111], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3173], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6768], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0059], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.024334
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.032586
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.070069
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.018059
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.027344
#
# Test set: Avg. loss: 0.3320, Accuracy: 9099/10000 (91%)
#
# tensor([0.4986], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1801], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3213], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3043], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6812], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0145], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.028699
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.018919
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.005700
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.050931
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.030024
#
# Test set: Avg. loss: 0.3314, Accuracy: 9098/10000 (91%)
#
# tensor([0.4974], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1753], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3273], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2887], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6885], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0228], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.050563
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.002834
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.031552
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.024119
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.007158
#
# Test set: Avg. loss: 0.3296, Accuracy: 9103/10000 (91%)
#
# tensor([0.4885], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1699], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3415], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2898], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6939], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0162], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.030319
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.167956
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.033143
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.070572
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.007486
#
# Test set: Avg. loss: 0.3301, Accuracy: 9094/10000 (91%)
#
# tensor([0.4789], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1841], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3370], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3012], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6827], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0161], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.097069
# Train Epoch: 11 [12800/60000 (21%)]	Loss: 0.020905
# Train Epoch: 11 [25600/60000 (43%)]	Loss: 0.010151
# Train Epoch: 11 [38400/60000 (64%)]	Loss: 0.019200
# Train Epoch: 11 [51200/60000 (85%)]	Loss: 0.070599
#
# Test set: Avg. loss: 0.3281, Accuracy: 9099/10000 (91%)
#
# tensor([0.5197], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1393], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3410], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2765], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7044], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0191], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.032226
# Train Epoch: 12 [12800/60000 (21%)]	Loss: 0.015950
# Train Epoch: 12 [25600/60000 (43%)]	Loss: 0.009219
# Train Epoch: 12 [38400/60000 (64%)]	Loss: 0.004988
# Train Epoch: 12 [51200/60000 (85%)]	Loss: 0.030189
#
# Test set: Avg. loss: 0.3268, Accuracy: 9103/10000 (91%)
#
# tensor([0.5153], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1573], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3274], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3101], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6899], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.031148
# Train Epoch: 13 [12800/60000 (21%)]	Loss: 0.014063
# Train Epoch: 13 [25600/60000 (43%)]	Loss: 0.027220
# Train Epoch: 13 [38400/60000 (64%)]	Loss: 0.031640
# Train Epoch: 13 [51200/60000 (85%)]	Loss: 0.044979
#
# Test set: Avg. loss: 0.3274, Accuracy: 9107/10000 (91%)
#
# tensor([0.4874], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1946], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3181], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2699], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6971], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0329], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.043219
# Train Epoch: 14 [12800/60000 (21%)]	Loss: 0.035373
# Train Epoch: 14 [25600/60000 (43%)]	Loss: 0.065636
# Train Epoch: 14 [38400/60000 (64%)]	Loss: 0.048991
# Train Epoch: 14 [51200/60000 (85%)]	Loss: 0.068801
#
# Test set: Avg. loss: 0.3303, Accuracy: 9098/10000 (91%)
#
# tensor([0.4736], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1745], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3519], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3032], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6822], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0146], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.021814
# Train Epoch: 15 [12800/60000 (21%)]	Loss: 0.090298
# Train Epoch: 15 [25600/60000 (43%)]	Loss: 0.031524
# Train Epoch: 15 [38400/60000 (64%)]	Loss: 0.018906
# Train Epoch: 15 [51200/60000 (85%)]	Loss: 0.033423
#
# Test set: Avg. loss: 0.3285, Accuracy: 9103/10000 (91%)
#
# tensor([0.5021], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1488], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3490], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2703], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7116], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0181], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.024600
# Train Epoch: 16 [12800/60000 (21%)]	Loss: 0.015853
# Train Epoch: 16 [25600/60000 (43%)]	Loss: 0.039874
# Train Epoch: 16 [38400/60000 (64%)]	Loss: 0.102142
# Train Epoch: 16 [51200/60000 (85%)]	Loss: 0.158187
#
# Test set: Avg. loss: 0.3294, Accuracy: 9111/10000 (91%)
#
# tensor([0.4888], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1664], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3448], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2676], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7097], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0227], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.089631
# Train Epoch: 17 [12800/60000 (21%)]	Loss: 0.030796
# Train Epoch: 17 [25600/60000 (43%)]	Loss: 0.037979
# Train Epoch: 17 [38400/60000 (64%)]	Loss: 0.016872
# Train Epoch: 17 [51200/60000 (85%)]	Loss: 0.087891
#
# Test set: Avg. loss: 0.3288, Accuracy: 9106/10000 (91%)
#
# tensor([0.5107], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1541], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2951], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7019], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0031], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.012568
# Train Epoch: 18 [12800/60000 (21%)]	Loss: 0.028053
# Train Epoch: 18 [25600/60000 (43%)]	Loss: 0.123413
# Train Epoch: 18 [38400/60000 (64%)]	Loss: 0.014590
# Train Epoch: 18 [51200/60000 (85%)]	Loss: 0.039225
#
# Test set: Avg. loss: 0.3291, Accuracy: 9090/10000 (91%)
#
# tensor([0.5016], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1605], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3380], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3188], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6812], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([6.9326e-06], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.033322
# Train Epoch: 19 [12800/60000 (21%)]	Loss: 0.020588
# Train Epoch: 19 [25600/60000 (43%)]	Loss: 0.033831
# Train Epoch: 19 [38400/60000 (64%)]	Loss: 0.048612
# Train Epoch: 19 [51200/60000 (85%)]	Loss: 0.031539
#
# Test set: Avg. loss: 0.3262, Accuracy: 9105/10000 (91%)
#
# tensor([0.4798], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1847], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3354], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2855], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.6973], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0171], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.111937
# Train Epoch: 20 [12800/60000 (21%)]	Loss: 0.026035
# Train Epoch: 20 [25600/60000 (43%)]	Loss: 0.014396
# Train Epoch: 20 [38400/60000 (64%)]	Loss: 0.012694
# Train Epoch: 20 [51200/60000 (85%)]	Loss: 0.034902
#
# Test set: Avg. loss: 0.3257, Accuracy: 9111/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.011395
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.013402
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.042554
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.041581
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.030674
#
# Test set: Avg. loss: 0.3425, Accuracy: 9106/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.013437
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.031756
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.011299
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.016536
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.177069
#
# Test set: Avg. loss: 0.3588, Accuracy: 9118/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.014479
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 0.054717
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.008364
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 0.026456
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.009133
#
# Test set: Avg. loss: 0.3978, Accuracy: 9009/10000 (90%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.044735
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 0.106599
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.031327
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 0.010379
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.003265
#
# Test set: Avg. loss: 0.3698, Accuracy: 9095/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.035148
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 0.009844
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.034654
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 0.010749
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.032063
#
# Test set: Avg. loss: 0.4177, Accuracy: 9084/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.053175
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 0.013920
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.015051
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 0.004380
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.007483
#
# Test set: Avg. loss: 0.4144, Accuracy: 9079/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.028872
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 0.026586
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.005828
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 0.014611
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.009244
#
# Test set: Avg. loss: 0.4292, Accuracy: 9137/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.006967
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 0.013201
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.036611
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 0.044546
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.034290
#
# Test set: Avg. loss: 0.4603, Accuracy: 9059/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.024465
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 0.024731
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.025075
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 0.033263
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.010531
#
# Test set: Avg. loss: 0.4233, Accuracy: 9135/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.015206
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 0.011592
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.012724
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 0.023052
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.006943
#
# Test set: Avg. loss: 0.4582, Accuracy: 9108/10000 (91%)
#
# tensor([0.5178], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.3352], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.2907], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.7001], device='cuda:0', grad_fn=<DivBackward0>)
# tensor([0.0091], device='cuda:0', grad_fn=<DivBackward0>)

# %%
torch.save(network, 'MNIST.pth')

# %%
network = torch.load('MNIST.pth')
network.eval()
# Out:
# Net(
#   (conv1): Conv2d(1, 20, kernel_size=(5, 5), stride=(1, 1))
#   (bn1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#   (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=800, out_features=500, bias=True)
#   (bn3): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
network.cpu()
import seaborn as sns
sns.set()
x = torch.Tensor(np.linspace(-3, 3))
plt.plot(x.cpu().detach().numpy(),(network.w1_1*F.relu(x)+network.w2_1*F.tanh(x)+network.w3_1*torch.sin(x)).detach().numpy()/(network.w1_1+network.w2_1+network.w3_1+1e-5).cpu().detach().numpy())
#plt.yscale('log')
plt.show()
plt.plot(x.cpu().detach().numpy(),(network.w1_2*F.relu(x)+network.w2_2*F.tanh(x)+network.w3_2*torch.sin(x)).detach().numpy()/(network.w1_2+network.w2_2+network.w3_2+1e-5).cpu().detach().numpy())
plt.show()
plt.plot(x.cpu().detach().numpy(),(network.w1_3*F.relu(x)+network.w2_3*F.tanh(x)+network.w3_3*torch.sin(x)).detach().numpy()/(network.w1_3+network.w2_3+network.w3_3+1e-5).cpu().detach().numpy())
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
fig = plt.figure()
plt.plot(train_counter, train_losses, color='blue')

train_losses1=train_losses
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.xlabel('Number of Training Examples Seen')
plt.ylabel('Negative Log Likelihood Loss')
fig

# %%
fig = plt.figure()
plt.plot(train_losses, color='blue')
plt.plot( test_losses, color='red')
train_losses1=train_losses
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.xlabel('Number of Training Examples Seen')
plt.ylabel('Negative Log Likelihood Loss')
fig

# %%
with torch.no_grad():
  output = network(example_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
fig = plt.figure()
for i in range(6):
  plt.subplot(2,3,i+1)
  plt.tight_layout()
  plt.imshow(example_data[i][0], cmap='gray', interpolation='none')
  plt.title("Prediction: {}".format(
    output.data.max(1, keepdim=True)[1][i].item()))
  plt.xticks([])
  plt.yticks([])
fig

# %%
network
# Out:
# Net(
#   (conv1): Conv2d(1, 20, kernel_size=(5, 5), stride=(1, 1))
#   (bn1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(20, 50, kernel_size=(5, 5), stride=(1, 1))
#   (bn2): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=800, out_features=500, bias=True)
#   (bn3): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
x = torch.Tensor(np.linspace(-3, 3))
plt.plot(x.cpu().detach().numpy(),(network.w1_1*F.relu(x)+network.w2_1*F.tanh(x)+network.w3_1*torch.sin(x)).detach().numpy()/(network.w1_1+network.w2_1+network.w3_1+1e-5).cpu().detach().numpy(),label='Layer 1')
plt.plot(x.cpu().detach().numpy(),(network.w1_2*F.relu(x)+network.w2_2*F.tanh(x)+network.w3_2*torch.sin(x)).detach().numpy()/(network.w1_2+network.w2_2+network.w3_2+1e-5).cpu().detach().numpy(),label='Layer 2')
plt.plot(x.cpu().detach().numpy(),(network.w1_3*F.relu(x)+network.w2_3*F.tanh(x)+network.w3_3*torch.sin(x)).detach().numpy()/(network.w1_3+network.w2_3+network.w3_3+1e-5).cpu().detach().numpy(),label='Layer 3')
plt.legend(ncol=1, loc='upper left');
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
  print(network.w1_1/(network.w1_1+network.w2_1+network.w3_1))
  print(network.w2_1/(network.w1_1+network.w2_1+network.w3_1))
  print(network.w3_1/(network.w1_1+network.w2_1+network.w3_1))
  print(network.w1_2/(network.w1_2+network.w2_2+network.w3_2))
  print(network.w2_2/(network.w1_2+network.w2_2+network.w3_2))
  print(network.w3_2/(network.w1_2+network.w2_2+network.w3_2))
  print(network.w1_3/(network.w1_3+network.w2_3+network.w3_3))
  print(network.w2_3/(network.w1_3+network.w2_3+network.w3_3))
  print(network.w3_3/(network.w1_3+network.w2_3+network.w3_3))
# Out:
# tensor([0.5178], grad_fn=<DivBackward0>)
# tensor([0.1470], grad_fn=<DivBackward0>)
# tensor([0.3352], grad_fn=<DivBackward0>)
# tensor([0.2907], grad_fn=<DivBackward0>)
# tensor([0.7001], grad_fn=<DivBackward0>)
# tensor([0.0091], grad_fn=<DivBackward0>)
# tensor([0.1221], grad_fn=<DivBackward0>)
# tensor([0.0410], grad_fn=<DivBackward0>)
# tensor([0.8369], grad_fn=<DivBackward0>)

# %%
x = torch.Tensor(np.linspace(-10, 10))
plt.plot(x.cpu().detach().numpy(),(network.w1_1*F.relu(x)+network.w2_1*F.tanh(x)+network.w3_1*torch.sin(x)).detach().numpy()/(network.w1_1+network.w2_1+network.w3_1+1e-5).cpu().detach().numpy(),label='Layer 1')
plt.plot(x.cpu().detach().numpy(),(network.w1_2*F.relu(x)+network.w2_2*F.tanh(x)+network.w3_2*torch.sin(x)).detach().numpy()/(network.w1_2+network.w2_2+network.w3_2+1e-5).cpu().detach().numpy(),label='Layer 2')
plt.plot(x.cpu().detach().numpy(),(network.w1_3*F.relu(x)+network.w2_3*F.tanh(x)+network.w3_3*torch.sin(x)).detach().numpy()/(network.w1_3+network.w2_3+network.w3_3+1e-5).cpu().detach().numpy(),label='Layer 3')
plt.legend(ncol=1, loc='upper left');
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
x = torch.Tensor(np.linspace(-100, 100))
plt.plot(x.cpu().detach().numpy(),(network.w1_1*F.relu(x)+network.w2_1*F.tanh(x)+network.w3_1*torch.sin(x)).detach().numpy()/(network.w1_1+network.w2_1+network.w3_1+1e-5).cpu().detach().numpy(),label='Layer 1')
plt.plot(x.cpu().detach().numpy(),(network.w1_2*F.relu(x)+network.w2_2*F.tanh(x)+network.w3_2*torch.sin(x)).detach().numpy()/(network.w1_2+network.w2_2+network.w3_2+1e-5).cpu().detach().numpy(),label='Layer 2')
plt.plot(x.cpu().detach().numpy(),(network.w1_3*F.relu(x)+network.w2_3*F.tanh(x)+network.w3_3*torch.sin(x)).detach().numpy()/(network.w1_3+network.w2_3+network.w3_3+1e-5).cpu().detach().numpy(),label='Layer 3')
plt.legend(ncol=1, loc='upper left');
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
x = torch.Tensor(np.linspace(-1, 1))
plt.plot(x.cpu().detach().numpy(),(network.w1_1*F.relu(x)+network.w2_1*F.tanh(x)+network.w3_1*torch.sin(x)).detach().numpy()/(network.w1_1+network.w2_1+network.w3_1+1e-5).cpu().detach().numpy(),label='Layer 1')
plt.plot(x.cpu().detach().numpy(),(network.w1_2*F.relu(x)+network.w2_2*F.tanh(x)+network.w3_2*torch.sin(x)).detach().numpy()/(network.w1_2+network.w2_2+network.w3_2+1e-5).cpu().detach().numpy(),label='Layer 2')
plt.plot(x.cpu().detach().numpy(),(network.w1_3*F.relu(x)+network.w2_3*F.tanh(x)+network.w3_3*torch.sin(x)).detach().numpy()/(network.w1_3+network.w2_3+network.w3_3+1e-5).cpu().detach().numpy(),label='Layer 3')
plt.legend(ncol=1, loc='upper left');
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1795: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
